# %% [markdown]
# **Background:**
#
# The purpose of this notebook is to transform a .wav file into a spectrogram and then feed it into a well known model such as InceptionV3 for feature generation

# %% [markdown]
# ## Libraries and File Locations

# %%
import sys
sys.path.append("..")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import soundfile
from scipy import signal
import librosa
import matplotlib.pyplot as plt
import specdisplay
from os import listdir
from os.path import isfile, join
import json

# %% [markdown]
# ## Define file generation parameters

# %% [markdown]
# **Number of Mel-frequencies to keep in the spectrograms**

# %%
n_mels = 128

# %% [markdown]
# ## Defining spectrogram transformation function

# %% [markdown]
# ## NOTE!!
#
# We're averaging across channels, come back and try a different approach if that's not working

# %%
def extract_spectrogram(samples,sample_rate,n_mels=128,n_fft=2048):
    feature_set = []
    if samples.shape[1:]:
        channels = samples.shape[1:][0]
    else:
        channels = 1
        samples = np.expand_dims(samples, axis=1)
    for i in range(channels):
        sample_channel_x = samples[:,i]
        mel_spectrogram = librosa.feature.melspectrogram(y=sample_channel_x, 
                                                     sr=sample_rate,
                                                     n_fft=n_fft, 
                                                     n_mels = n_mels
                                                        )
        decibel_spec = librosa.logamplitude(mel_spectrogram,ref_power=np.max)
        feature_set.append(decibel_spec)
    feature_set = np.array(feature_set)
    feature_set = np.mean(feature_set,axis=0)
    return feature_set

# %% [markdown]
# # Creating the PNG spectrograms

# %%
samples_folder = "/home/romulo/github/soundflux/samples"

# %% [markdown]
# # Read all of the json files

# %%
metadata = [samples_folder+"/"+ f for f in listdir(samples_folder) if isfile(join(samples_folder, f)) and ".json" in f]

# %%
data = []
error_count = 0
for fi in metadata:
    log = open(fi, "r").read()
    try:
        d = json.loads(log)
        data.append(d)
    except Exception as e:
        error_count +=1
        print("Error number {}".format(error_count))
# Out:
# Error number 1

# %%
dataset = pd.DataFrame(data)

# %%
dataset
# Out:
#                                    audio_file             class  \
# 0       randy_sample_id_1550376990.526841.wav     falling_dummy
# 1       randy_sample_id_1550717099.515901.wav     falling_dummy
# 2      negative_sample_id_1551026129.0965.wav     general_noise
# 3       randy_sample_id_1551319808.967742.wav     falling_dummy
# 4    negative_sample_id_1551538987.462724.wav     general_noise
# 5    negative_sample_id_1551026054.854264.wav     general_noise
# 6      random_sample_id_1549763978.971404.wav  background_music
# 7       randy_sample_id_1550631021.192445.wav     falling_dummy
# 8       randy_sample_id_1551319650.225114.wav     falling_dummy
# 9     negative_sample_id_1551407094.99554.wav     general_noise
# 10    negative_sample_id_1550509622.27022.wav     general_noise
# 11      randy_sample_id_1550428594.822552.wav     falling_dummy
# 12      randy_sample_id_1551552428.634176.wav     falling_dummy
# 13      randy_sample_id_1550377033.598056.wav     falling_dummy
# 14      randy_sample_id_1550542000.722717.wav     falling_dummy
# 15      randy_sample_id_1550542038.848638.wav     falling_dummy
# 16   negative_sample_id_1551541838.142322.wav     general_noise
# 17    negative_sample_id_1551319081.20396.wav     general_noise
# 18   negative_sample_id_1551407112.316995.wav     general_noise
# 19      randy_sample_id_1550542385.073125.wav     falling_dummy
# 20   negative_sample_id_1551026165.288704.wav     general_noise
# 21     random_sample_id_1549765064.956834.wav    falling_object
# 22   negative_sample_id_1551552586.615781.wav     general_noise
# 23   negative_sample_id_1551542663.473948.wav     general_noise
# 24      negative_sample_id_1550630627.708.wav     general_noise
# 25      randy_sample_id_1550429379.929382.wav     falling_dummy
# 26   negative_sample_id_1550630645.001007.wav     general_noise
# 27   negative_sample_id_1551552608.213222.wav     general_noise
# 28      randy_sample_id_1551552035.841841.wav     falling_dummy
# 29   negative_sample_id_1551407139.379022.wav     general_noise
# ..                                        ...               ...
# 140  negative_sample_id_1551542550.384436.wav     general_noise
# 141  negative_sample_id_1551407806.449409.wav     general_noise
# 142  negative_sample_id_1550716618.364342.wav     general_noise
# 143  negative_sample_id_1551542615.133203.wav     general_noise
# 144  negative_sample_id_1551550927.552134.wav     general_noise
# 145  negative_sample_id_1551539014.726098.wav     general_noise
# 146  negative_sample_id_1551026108.124052.wav     general_noise
# 147     randy_sample_id_1550446383.199345.wav     falling_dummy
# 148     randy_sample_id_1551552151.190424.wav     falling_dummy
# 149      randy_sample_id_1550378080.52238.wav     falling_dummy
# 150     randy_sample_id_1550716976.508431.wav     falling_dummy
# 151      randy_sample_id_1550540712.25005.wav     falling_dummy
# 152     randy_sample_id_1551551344.941684.wav     falling_dummy
# 153     randy_sample_id_1551552305.233316.wav     falling_dummy
# 154     randy_sample_id_1550428724.262841.wav     falling_dummy
# 155     randy_sample_id_1550509945.248546.wav     falling_dummy
# 156     randy_sample_id_1550630932.130811.wav     falling_dummy
# 157     randy_sample_id_1551551120.082622.wav     falling_dummy
# 158  negative_sample_id_1551542688.417571.wav     general_noise
# 159     randy_sample_id_1551027291.622672.wav     falling_dummy
# 160     randy_sample_id_1550631136.339238.wav     falling_dummy
# 161     randy_sample_id_1551552123.248266.wav     falling_dummy
# 162  negative_sample_id_1551320267.416806.wav     general_noise
# 163     randy_sample_id_1551320088.937952.wav     falling_dummy
# 164    random_sample_id_1549764985.327645.wav      falling_book
# 165  negative_sample_id_1551319111.945776.wav     general_noise
# 166     randy_sample_id_1551406591.627884.wav     falling_dummy
# 167      randy_sample_id_1551552177.78427.wav     falling_dummy
# 168      randy_sample_id_1551026699.53443.wav     falling_dummy
# 169     randy_sample_id_1551320000.428542.wav     falling_dummy
#
#                     id                                       index_file  \
# 0    1550376990.526841     randy_sample_id_1550376990.526841_index.json
# 1    1550717099.515901     randy_sample_id_1550717099.515901_index.json
# 2      1551026129.0965    negative_sample_id_1551026129.0965_index.json
# 3    1551319808.967742     randy_sample_id_1551319808.967742_index.json
# 4    1551538987.462724  negative_sample_id_1551538987.462724_index.json
# 5    1551026054.854264  negative_sample_id_1551026054.854264_index.json
# 6    1549763978.971404    random_sample_id_1549763978.971404_index.json
# 162  1551320267.416806  negative_sample_id_1551320267.416806_index.json
# 163  1551320088.937952     randy_sample_id_1551320088.937952_index.json
# 164  1549764985.327645    random_sample_id_1549764985.327645_index.json
# 165  1551319111.945776  negative_sample_id_1551319111.945776_index.json
# 166  1551406591.627884     randy_sample_id_1551406591.627884_index.json
# 167   1551552177.78427      randy_sample_id_1551552177.78427_index.json
# 168   1551026699.53443      randy_sample_id_1551026699.53443_index.json
# 169  1551320000.428542     randy_sample_id_1551320000.428542_index.json
#
#                                               metadata           prefix  \
# 0    {'floor_type': 'wooden_floor', 'distance_from_...     randy_sample
# 1    {'floor_type': 'carpet_room3', 'distance_from_...     randy_sample
# 2    {'distance_from_device': 72, 'floor_type': 'wo...  negative_sample
# 3    {'distance_from_device': 180, 'floor_type': 'w...     randy_sample
# 4    {'distance_from_device': 96, 'floor_type': 'wo...  negative_sample
# 5    {'distance_from_device': 72, 'floor_type': 'wo...  negative_sample
# 6                                                  NaN    random_sample
# 7    {'distance_from_device': 108, 'floor_type': 'c...     randy_sample
# 8    {'distance_from_device': 180, 'floor_type': 'w...     randy_sample
# 9    {'distance_from_device': 84, 'floor_type': 'wo...  negative_sample
# 10   {'distance_from_device': 120, 'floor_type': 'c...  negative_sample
# 11   {'distance_from_device': 144, 'floor_type': 'c...     randy_sample
# 12   {'floor_type': 'wooden_livingroom_stairs', 'di...     randy_sample
# 13   {'floor_type': 'wooden_floor', 'distance_from_...     randy_sample
# 14   {'distance_from_device': 120, 'floor_type': 'w...     randy_sample
# 15   {'distance_from_device': 120, 'floor_type': 'w...     randy_sample
# 16   {'distance_from_device': 36, 'floor_type': 'ca...  negative_sample
# 17   {'distance_from_device': 180, 'floor_type': 'w...  negative_sample
# 18   {'distance_from_device': 84, 'floor_type': 'wo...  negative_sample
# 19   {'distance_from_device': 240, 'floor_type': 'w...     randy_sample
# 20   {'distance_from_device': 72, 'floor_type': 'wo...  negative_sample
# 21                                                 NaN    random_sample
# 22   {'floor_type': 'wooden_livingroom_stairs', 'di...  negative_sample
# 23   {'distance_from_device': 36, 'floor_type': 'ca...  negative_sample
# 24   {'distance_from_device': 240, 'floor_type': 'c...  negative_sample
# 25   {'distance_from_device': 144, 'floor_type': 'c...     randy_sample
# 26   {'distance_from_device': 240, 'floor_type': 'c...  negative_sample
# 27   {'floor_type': 'wooden_livingroom_stairs', 'di...  negative_sample
# 28   {'floor_type': 'wooden_livingroom_stairs', 'di...     randy_sample
# 29   {'distance_from_device': 84, 'floor_type': 'wo...  negative_sample
# ..                                                 ...              ...
# 140  {'distance_from_device': 36, 'floor_type': 'ca...  negative_sample
# 141  {'distance_from_device': 60, 'floor_type': 'ca...  negative_sample
# 142  {'floor_type': 'carpet_room3', 'distance_from_...  negative_sample
# 143  {'distance_from_device': 36, 'floor_type': 'ca...  negative_sample
# 144  {'distance_from_device': 36, 'floor_type': 'ca...  negative_sample
# 145  {'distance_from_device': 96, 'floor_type': 'wo...  negative_sample
# 146  {'distance_from_device': 72, 'floor_type': 'wo...  negative_sample
# 147  {'distance_from_device': 144, 'floor_type': 'c...     randy_sample
# 148  {'floor_type': 'wooden_livingroom_stairs', 'di...     randy_sample
# 149  {'floor_type': 'wooden_floor', 'distance_from_...     randy_sample
# 150  {'floor_type': 'carpet_room3', 'distance_from_...     randy_sample
# 151  {'distance_from_device': 120, 'floor_type': 'w...     randy_sample
# 152  {'distance_from_device': 92, 'floor_type': 'ca...     randy_sample
# 153  {'floor_type': 'wooden_livingroom_stairs', 'di...     randy_sample
# 154  {'distance_from_device': 144, 'floor_type': 'c...     randy_sample
# 155  {'distance_from_device': 120, 'floor_type': 'c...     randy_sample
# 156  {'distance_from_device': 108, 'floor_type': 'c...     randy_sample
# 157  {'distance_from_device': 36, 'floor_type': 'ca...     randy_sample
# 158  {'distance_from_device': 36, 'floor_type': 'ca...  negative_sample
# 159  {'distance_from_device': 192, 'floor_type': 'w...     randy_sample
# 160  {'distance_from_device': 108, 'floor_type': 'c...     randy_sample
# 161  {'floor_type': 'wooden_livingroom_stairs', 'di...     randy_sample
# 162  {'distance_from_device': 48, 'floor_type': 'wo...  negative_sample
# 163  {'distance_from_device': 96, 'floor_type': 'wo...     randy_sample
# 164                                                NaN    random_sample
# 165  {'distance_from_device': 180, 'floor_type': 'w...  negative_sample
# 166  {'distance_from_device': 48, 'floor_type': 'ca...     randy_sample
# 167  {'floor_type': 'wooden_livingroom_stairs', 'di...     randy_sample
# 168  {'distance_from_device': 192, 'floor_type': 'w...     randy_sample
# 169  {'distance_from_device': 96, 'floor_type': 'wo...     randy_sample
#
#      sample_length             timestamp  \
# 0                4  02/17/2019, 04:16:30
# 1                4  02/21/2019, 02:44:59
# 2                4  02/24/2019, 16:35:29
# 3                4  02/28/2019, 02:10:08
# 4                4  03/02/2019, 15:03:07
# 5                4  02/24/2019, 16:34:14
# 6                4  02/10/2019, 01:59:38
# 7                4  02/20/2019, 02:50:21
# 8                4  02/28/2019, 02:07:30
# 9                4  03/01/2019, 02:24:54
# 10               4  02/18/2019, 17:07:02
# 11               4  02/17/2019, 18:36:34
# 12               4  03/02/2019, 18:47:08
# 13               4  02/17/2019, 04:17:13
# 14               4  02/19/2019, 02:06:40
# 15               4  02/19/2019, 02:07:18
# 16               4  03/02/2019, 15:50:38
# 17               4  02/28/2019, 01:58:01
# 18               4  03/01/2019, 02:25:12
# 19               4  02/19/2019, 02:13:05
# 20               4  02/24/2019, 16:36:05
# 21               4  02/10/2019, 02:17:44
# 22               4  03/02/2019, 18:49:46
# 23               4  03/02/2019, 16:04:23
# 24               4  02/20/2019, 02:43:47
# 25               4  02/17/2019, 18:49:39
# 26               4  02/20/2019, 02:44:05
# 27               4  03/02/2019, 18:50:08
# 28               4  03/02/2019, 18:40:35
# 29               4  03/01/2019, 02:25:39
# ..             ...                   ...
# 140              4  03/02/2019, 16:02:30
# 141              4  03/01/2019, 02:36:46
# 142              4  02/21/2019, 02:36:58
# 143              4  03/02/2019, 16:03:35
# 144              4  03/02/2019, 18:22:07
# 145              4  03/02/2019, 15:03:34
# 146              4  02/24/2019, 16:35:08
# 147              4  02/17/2019, 23:33:03
# 148              4  03/02/2019, 18:42:31
# 149              4  02/17/2019, 04:34:40
# 150              4  02/21/2019, 02:42:56
# 151              4  02/19/2019, 01:45:12
# 152              4  03/02/2019, 18:29:04
# 153              4  03/02/2019, 18:45:05
# 154              4  02/17/2019, 18:38:44
# 155              4  02/18/2019, 17:12:25
# 156              4  02/20/2019, 02:48:52
# 157              4  03/02/2019, 18:25:20
# 158              4  03/02/2019, 16:04:48
# 159              4  02/24/2019, 16:54:51
# 160              4  02/20/2019, 02:52:16
# 161              4  03/02/2019, 18:42:03
# 162              4  02/28/2019, 02:17:47
# 163              4  02/28/2019, 02:14:48
# 164              4  02/10/2019, 02:16:25
# 165              4  02/28/2019, 01:58:31
# 166              4  03/01/2019, 02:16:31
# 167              4  03/02/2019, 18:42:57
# 168              4  02/24/2019, 16:44:59
# 169              4  02/28/2019, 02:13:20
#
#                                         vibration_file
# 0     randy_sample_id_1550376990.526841_vibration.json
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6    random_sample_id_1549763978.971404_vibration.json
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13    randy_sample_id_1550377033.598056_vibration.json
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21   random_sample_id_1549765064.956834_vibration.json
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149    randy_sample_id_1550378080.52238_vibration.json
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
# 157                                                NaN
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164  random_sample_id_1549764985.327645_vibration.json
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
#
# [170 rows x 9 columns]

# %%
target_folder = "/media/romulo/6237-3231/randy_samples"

# %%
for index, row in dataset[::].iterrows():
    print("Transforming file {}".format(index))
    
    if not os.path.exists(target_folder + "/"+'spectrograms'):
        os.makedirs(target_folder + "/"+'spectrograms')
    
    if not os.path.exists(target_folder + "/"+'spectrograms/' + row['class']):
        os.makedirs(target_folder + "/"+'spectrograms/' + row['class'])

    # Convert to log scale (dB). We'll use the peak power as reference.
    y, sr = soundfile.read(samples_folder + "/"+ str(row['audio_file']))
    log_s = extract_spectrogram(y,sr,n_mels=n_mels,n_fft=2048)
    #new plot
    fig = plt.figure(figsize=(12,4))
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)

    #getting spectrogram
    specdisplay.specshow(log_s, sr=sr, x_axis='time', y_axis='mel')

    #Saving PNG
    plt.savefig(target_folder + "/"+'spectrograms/' + row['class'] + 
                '/' + row['id'] + '.png')
    plt.close()
# Out:
# Transforming file 0
# ../specdisplay.py:676: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#